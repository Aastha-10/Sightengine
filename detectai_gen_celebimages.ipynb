# %%
import os
import requests
import json

folder_path = r"C:\Users\aastha\.vscode\extensions\sourcery.sourcery-1.37.0-win32-x64\New folder\US_CELEBS_MALE"
api_user = '1838034711'   
api_secret = 'TkPXwbZ6Bm7CDHc5Re8KEsRHgFxFSjjU' 
models = 'genai'

for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.webp', '.bmp', '.gif')):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'rb') as image_file:
            files = {'media': image_file}
            params = {
                'models': models,
                'api_user': api_user,
                'api_secret': api_secret
            }
            response = requests.post('https://api.sightengine.com/1.0/check.json', files=files, data=params)
            output = json.loads(response.text)
            print(f"Results for {filename}:\n{json.dumps(output, indent=2)}\n")
# Out:
# Results for brad pitt.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNbL8dAlquUhCgI2oTWX",
#     "timestamp": 1752568654.545905,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNbCIlg7gu701o4rzy6q",
#     "uri": "brad pitt.webp"
#   }
# }
#
# Results for chris evans.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNbwb1if4QqMZCaukyWi",
#     "timestamp": 1752568655.949658,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNbpMItUfO96hRAU3IKc",
#     "uri": "chris evans.webp"
#   }
# }
#
# Results for eddie murphy.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNbYHWvUsMiFFeV6XNLM",
#     "timestamp": 1752568657.10246,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNblyrpYzbB6UdYrNCmG",
#     "uri": "eddie murphy.webp"
#   }
# }
#
# ...

# %%
import os
import requests
import json

folder_path = r"C:\Users\aastha\.vscode\extensions\sourcery.sourcery-1.37.0-win32-x64\New folder\US_CELEBS_FEMALES"
api_user = '1838034711'   
api_secret = 'TkPXwbZ6Bm7CDHc5Re8KEsRHgFxFSjjU' 
models = 'genai'

for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.webp', '.bmp', '.gif')):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'rb') as image_file:
            files = {'media': image_file}
            params = {
                'models': models,
                'api_user': api_user,
                'api_secret': api_secret
            }
            response = requests.post('https://api.sightengine.com/1.0/check.json', files=files, data=params)
            output = json.loads(response.text)
            print(f"Results for {filename}:\n{json.dumps(output, indent=2)}\n")
# Out:
# Results for Angelina Jolie.jpg:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNezRnD0bvuM4vmMcf2G",
#     "timestamp": 1752568805.393897,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNeYf3Jku5vU0LTQV4XH",
#     "uri": "Angelina Jolie.jpg"
#   }
# }
#
# Results for camila cabello.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNepgkCEtcjMtNKOrYdl",
#     "timestamp": 1752568806.188009,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNeSwwRG73z7OQtfAf8p",
#     "uri": "camila cabello.webp"
#   }
# }
#
# Results for emma stone.jpg:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNez4WqprQ3qnwWG43nA",
#     "timestamp": 1752568807.139974,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNeqAwSlFfq2cDuCpbF2",
#     "uri": "emma stone.jpg"
# ...

# %%
import os
import requests
import json

folder_path = r"C:\Users\aastha\.vscode\extensions\sourcery.sourcery-1.37.0-win32-x64\New folder\WORLD_CELEBS_F"
api_user = '1838034711'   
api_secret = 'TkPXwbZ6Bm7CDHc5Re8KEsRHgFxFSjjU' 
models = 'genai'

for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.webp', '.bmp', '.gif')):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'rb') as image_file:
            files = {'media': image_file}
            params = {
                'models': models,
                'api_user': api_user,
                'api_secret': api_secret
            }
            response = requests.post('https://api.sightengine.com/1.0/check.json', files=files, data=params)
            output = json.loads(response.text)
            print(f"Results for {filename}:\n{json.dumps(output, indent=2)}\n")
# Out:
# Results for blackpink rose.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNgB4BUo4HRTG4no7R6B",
#     "timestamp": 1752568921.664749,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNgAFhylS9gd4mHzcv8z",
#     "uri": "blackpink rose.webp"
#   }
# }
#
# Results for eiza gonzalez.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNgwOSRz2ZjMgNVgoiv8",
#     "timestamp": 1752568922.789592,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNg6iv0g6yMrpT4FABZv",
#     "uri": "eiza gonzalez.webp"
#   }
# }
#
# Results for emma watson.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNg9PDpm2uARG2Z1GJxT",
#     "timestamp": 1752568923.425644,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNgRwH0sL9WyR8nHnYy9",
#     "uri": "emma watson.webp"
# ...

# %%
import os
import requests
import json

folder_path = r"C:\Users\aastha\.vscode\extensions\sourcery.sourcery-1.37.0-win32-x64\New folder\WORLD_CELEBS_M"
api_user = '1838034711'   
api_secret = 'TkPXwbZ6Bm7CDHc5Re8KEsRHgFxFSjjU' 
models = 'genai'

for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.webp', '.bmp', '.gif')):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'rb') as image_file:
            files = {'media': image_file}
            params = {
                'models': models,
                'api_user': api_user,
                'api_secret': api_secret
            }
            response = requests.post('https://api.sightengine.com/1.0/check.json', files=files, data=params)
            output = json.loads(response.text)
            print(f"Results for {filename}:\n{json.dumps(output, indent=2)}\n")
# Out:
# Results for barak obama.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNgq3DSYmzbStzURLGB1",
#     "timestamp": 1752568950.18135,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNg9SA6bbEv1BCYzxzZX",
#     "uri": "barak obama.webp"
#   }
# }
#
# Results for bruce lee.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNgMFaGJBtDhbUXXKfL0",
#     "timestamp": 1752568950.983661,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.73
#   },
#   "media": {
#     "id": "med_iPNgVhjAKhWcgUhfGQdVz",
#     "uri": "bruce lee.webp"
#   }
# }
#
# Results for chris evans.webp:
# {
#   "status": "success",
#   "request": {
#     "id": "req_iPNgrGrWeiLhBy1q1ega1",
#     "timestamp": 1752568951.814551,
#     "operations": 5
#   },
#   "type": {
#     "ai_generated": 0.99
#   },
#   "media": {
#     "id": "med_iPNgUxqCDupmgOqhP7vQ8",
#     "uri": "chris evans.webp"
#   }
# }
#
# ...
